# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Social_Network_Ads.csv')

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0         True
# 1    15810944   35            20000          0         True
# 2    15668575   26            43000          0        False
# 3    15603246   27            57000          0        False
# 4    15804002   19            76000          0         True
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1        False
# 396  15706071   51            23000          1         True
# 397  15654296   50            20000          1        False
# 398  15755018   36            33000          0         True
# 399  15594041   49            36000          1        False
#
# [400 rows x 5 columns]

# %%
indep=dataset[['Age', 'EstimatedSalary','Gender_Male']]
dep=dataset['Purchased']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.svm import SVC

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'kernel':['linear','rbf','poly','sigmoid'],
             'gamma':['auto','scale'],
             'C':[10,100,1000,2000,3000]} 



grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3,n_jobs=-1,scoring='f1_weighted') 
   

grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# GridSearchCV(estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['linear', 'rbf', 'poly', 'sigmoid']},
#              scoring='f1_weighted', verbose=3)

# %%
re=grid.cv_results_

grid_predictions = grid.predict(X_test) 
   

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, grid_predictions)




from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}: 0.9100355779243318

# %%
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[80  5]
#  [ 7 42]]

# %%
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93        85
#            1       0.89      0.86      0.88        49
#
#     accuracy                           0.91       134
#    macro avg       0.91      0.90      0.90       134
# weighted avg       0.91      0.91      0.91       134

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC


svm_model = SVC(probability=True)


param_grid = {
    'C': [0.1, 1, 10, 100],
    'gamma': [1, 0.1, 0.01, 0.001],
    'kernel': ['rbf']
}


grid = GridSearchCV(svm_model, param_grid, refit=True, verbose=3)


grid.fit(X_train, y_train)


probabilities = grid.predict_proba(X_test)[:, 1]


roc_auc = roc_auc_score(y_test, probabilities)
print(f"ROC AUC Score: {roc_auc}")
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.852 total time=   0.0s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.849 total time=   0.0s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.792 total time=   0.0s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.906 total time=   0.0s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.849 total time=   0.0s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.796 total time=   0.0s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.774 total time=   0.0s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.717 total time=   0.0s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.925 total time=   0.0s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.868 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.648 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.660 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.642 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.642 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.642 total time=   0.0s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.648 total time=   0.0s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.660 total time=   0.0s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.642 total time=   0.0s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.642 total time=   0.0s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.642 total time=   0.0s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.889 total time=   0.0s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.906 total time=   0.0s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.849 total time=   0.0s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.943 total time=   0.0s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.962 total time=   0.0s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.889 total time=   0.0s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.849 total time=   0.0s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.849 total time=   0.0s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.943 total time=   0.0s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.962 total time=   0.0s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.759 total time=   0.0s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.755 total time=   0.0s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.698 total time=   0.0s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.887 total time=   0.0s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.868 total time=   0.0s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.648 total time=   0.0s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.660 total time=   0.0s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.642 total time=   0.0s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.642 total time=   0.0s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.642 total time=   0.0s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.870 total time=   0.0s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.906 total time=   0.0s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.868 total time=   0.0s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.925 total time=   0.0s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.943 total time=   0.0s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.889 total time=   0.0s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.868 total time=   0.0s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.849 total time=   0.0s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.943 total time=   0.0s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.962 total time=   0.0s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.815 total time=   0.0s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.811 total time=   0.0s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.736 total time=   0.0s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.943 total time=   0.0s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.906 total time=   0.0s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.741 total time=   0.0s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.755 total time=   0.0s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.679 total time=   0.0s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.849 total time=   0.0s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.868 total time=   0.0s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.870 total time=   0.0s
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.887 total time=   0.0s
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.792 total time=   0.0s
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.868 total time=   0.0s
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.925 total time=   0.0s
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.889 total time=   0.0s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.887 total time=   0.0s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.849 total time=   0.0s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.943 total time=   0.0s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.925 total time=   0.0s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.870 total time=   0.0s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.849 total time=   0.0s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.830 total time=   0.0s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.943 total time=   0.0s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.962 total time=   0.0s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.796 total time=   0.0s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.774 total time=   0.0s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.717 total time=   0.0s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.925 total time=   0.0s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.887 total time=   0.0s
# ROC AUC Score: 0.9567827130852341

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.014407      0.005036         0.010336        0.002172      10
# 1        0.006882      0.002265         0.006179        0.001272      10
# 2        0.004895      0.002642         0.001999        0.002529      10
# 3        0.006251      0.007655         0.006250        0.007655      10
# 4        0.003125      0.006250         0.012500        0.006250      10
# 5        0.009375      0.007654         0.003125        0.006249      10
# 6        0.006249      0.007654         0.003125        0.006249      10
# 7        0.006250      0.007655         0.003125        0.006250      10
# 8        0.018750      0.006250         0.006250        0.007655     100
# 9        0.003125      0.006250         0.009374        0.007654     100
# 10       0.021874      0.007655         0.006250        0.007655     100
# 11       0.000000      0.000000         0.008947        0.011759     100
# 12       0.024771      0.007481         0.004559        0.006191     100
# 13       0.006256      0.009350         0.009783        0.007241     100
# 14       0.029050      0.017404         0.007050        0.007153     100
# 15       0.004924      0.005725         0.001873        0.002313     100
# 16       0.104405      0.021049         0.004779        0.006298    1000
# 17       0.012008      0.006304         0.004732        0.005768    1000
# 18       0.166399      0.032362         0.003126        0.006251    1000
# 19       0.003125      0.006250         0.003125        0.006251    1000
# 20       0.106246      0.015308         0.003125        0.006250    1000
# 21       0.009375      0.007654         0.006251        0.007655    1000
# 22       0.231220      0.139433         0.000800        0.001600    1000
# 23       0.006250      0.007655         0.003125        0.006250    1000
# 24       0.246169      0.145093         0.007049        0.007152    2000
# 25       0.015623      0.000001         0.003125        0.006250    2000
# 26       0.367911      0.100930         0.003925        0.006052    2000
# 27       0.006251      0.007655         0.005546        0.006883    2000
# 28       0.247946      0.144223         0.003125        0.006250    2000
# 29       0.018750      0.006249         0.009375        0.007654    2000
# 30       0.356251      0.093496         0.006250        0.007654    2000
# 31       0.003125      0.006250         0.003125        0.006251    2000
# 32       0.275382      0.051048         0.000000        0.000000    3000
# 33       0.021875      0.007654         0.009374        0.007654    3000
# 34       0.498091      0.159554         0.000000        0.000000    3000
# 35       0.003126      0.006251         0.003125        0.006250    3000
# 36       0.269622      0.044612         0.003125        0.006250    3000
# 37       0.021874      0.007654         0.009375        0.007655    3000
# 38       0.543260      0.175988         0.000000        0.000000    3000
# 39       0.003125      0.006251         0.003125        0.006250    3000
#
#    param_gamma param_kernel  \
# 0         auto       linear
# 1         auto          rbf
# 2         auto         poly
# 3         auto      sigmoid
# 4        scale       linear
# 5        scale          rbf
# 6        scale         poly
# 7        scale      sigmoid
# 8         auto       linear
# 9         auto          rbf
# 10        auto         poly
# 11        auto      sigmoid
# 12       scale       linear
# 13       scale          rbf
# 14       scale         poly
# 15       scale      sigmoid
# 16        auto       linear
# 17        auto          rbf
# 18        auto         poly
# 19        auto      sigmoid
# 20       scale       linear
# 21       scale          rbf
# 22       scale         poly
# 23       scale      sigmoid
# 24        auto       linear
# 25        auto          rbf
# 26        auto         poly
# 27        auto      sigmoid
# 28       scale       linear
# 29       scale          rbf
# 30       scale         poly
# 31       scale      sigmoid
# 32        auto       linear
# 33        auto          rbf
# 34        auto         poly
# 35        auto      sigmoid
# 36       scale       linear
# 37       scale          rbf
# 38       scale         poly
# 39       scale      sigmoid
#
#                                                params  split0_test_score  \
# 0      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 1         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}           0.867478
# 2        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.799620
# 3     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.762677
# 4     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
# 5        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}           0.867478
# 6       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.799620
# 7    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.762677
# 8     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 9        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.867478
# 10      {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.822092
# 11   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.808927
# 12   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
# 13      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.867478
# 14     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.822092
# 15  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.808927
# 16   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 17      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.826263
# 18     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.822092
# 19  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.791752
# 20  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
# 21     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.847141
# 22    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.822092
# 23  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.808927
# 24   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 25      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.826263
# 26     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.822092
# 27  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.791752
# 28  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
# 29     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.826263
# 30    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.822092
# 31  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...           0.808927
# 32   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 33      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.826263
# 34     {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}           0.822092
# 35  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.791752
# 36  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
# 37     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           0.826263
# 38    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}           0.822092
# 39  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...           0.808927
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.790949           0.698235           0.923510
# 1            0.886792           0.869709           0.944161
# 2            0.808392           0.787943           0.924528
# 3            0.738916           0.655795           0.796284
# 4            0.790949           0.698235           0.923510
# 5            0.886792           0.869709           0.944161
# 6            0.808392           0.787943           0.924528
# 7            0.738916           0.753180           0.778067
# 8            0.790949           0.698235           0.923510
# 9            0.886792           0.870362           0.944161
# 10           0.787284           0.766556           0.924528
# 11           0.714931           0.633719           0.718497
# 12           0.790949           0.698235           0.923510
# 13           0.886792           0.870362           0.944161
# 14           0.787284           0.766556           0.924528
# 15           0.714931           0.698113           0.796284
# 16           0.790949           0.698235           0.923510
# 17           0.866968           0.851527           0.925272
# 18           0.765553           0.766556           0.924528
# 19           0.714931           0.698113           0.796284
# 20           0.790949           0.698235           0.923510
# 21           0.866968           0.851527           0.925272
# 22           0.765553           0.766556           0.924528
# 23           0.714931           0.698113           0.796284
# 24           0.790949           0.698235           0.923510
# 25           0.866968           0.851527           0.886792
# 26           0.765553           0.766556           0.924528
# 27           0.714931           0.698113           0.796284
# 28           0.790949           0.698235           0.923510
# 29           0.866968           0.851527           0.886792
# 30           0.765553           0.766556           0.924528
# 31           0.714931           0.698113           0.796284
# 32           0.790949           0.698235           0.923510
# 33           0.866968           0.851527           0.847020
# 34           0.765553           0.766556           0.924528
# 35           0.714931           0.698113           0.796284
# 36           0.790949           0.698235           0.923510
# 37           0.866968           0.851527           0.847020
# 38           0.765553           0.766556           0.924528
# 39           0.714931           0.698113           0.796284
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.901744         0.818146        0.083619               21
# 1            0.943041         0.902236        0.034431                3
# 2            0.901744         0.844445        0.056918               11
# 3            0.766556         0.744045        0.047743               39
# 4            0.901744         0.818146        0.083619               21
# 5            0.943041         0.902236        0.034431                3
# 6            0.901744         0.844445        0.056918               11
# 7            0.766556         0.759879        0.013172               31
# 8            0.901744         0.818146        0.083619               21
# 9            0.943041         0.902367        0.034308                1
# 10           0.901744         0.840441        0.062370               13
# 11           0.766556         0.728526        0.058625               40
# 12           0.901744         0.818146        0.083619               21
# 13           0.943041         0.902367        0.034308                1
# 14           0.901744         0.840441        0.062370               13
# 15           0.766556         0.756962        0.043745               32
# 16           0.901744         0.818146        0.083619               21
# 17           0.923510         0.878708        0.039503                6
# 18           0.901744         0.836095        0.066541               15
# 19           0.766556         0.753527        0.040048               36
# 20           0.901744         0.818146        0.083619               21
# 21           0.923510         0.882884        0.034529                5
# 22           0.901744         0.836095        0.066541               15
# 23           0.766556         0.756962        0.043745               32
# 24           0.901744         0.818146        0.083619               21
# 25           0.903610         0.867032        0.026948                7
# 26           0.901744         0.836095        0.066541               15
# 27           0.766556         0.753527        0.040048               36
# 28           0.901744         0.818146        0.083619               21
# 29           0.903610         0.867032        0.026948                7
# 30           0.901744         0.836095        0.066541               15
# 31           0.766556         0.756962        0.043745               32
# 32           0.901744         0.818146        0.083619               21
# 33           0.883278         0.855011        0.019206                9
# 34           0.901744         0.836095        0.066541               15
# 35           0.766556         0.753527        0.040048               36
# 36           0.901744         0.818146        0.083619               21
# 37           0.883278         0.855011        0.019206                9
# 38           0.901744         0.836095        0.066541               15
# 39           0.766556         0.756962        0.043745               32

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 24
# BMI: 42
# Children: 1
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction = grid.predict([[age_input, bmi_input, children_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[1]
